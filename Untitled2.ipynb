# %%
#PROGRAM TO FIND SQUARE ROOT
number = float(input("enter a number: "))
sqrt = number ** 0.5
print("square root:", sqrt)
# Out:
# enter a number: 121
# square root: 11.0

# %%
#solve Quadratic equation
import cmath

a =int(input('enter value of a: '))
b = int(input('enter value of b: '))
c = int(input('enter value of c: '))

# calculate the discriminant
d = (b**2) - (4*a*c)

# find two solutions
sol1 = (-b-cmath.sqrt(d))/(2*a)

sol2 = (-b+cmath.sqrt(d))/(2*a)

print('The solution are {0} and {1}'.format(sol1,sol2))
# Out:
# enter value of a: 2
# enter value of b: 3
# enter value of c: 4
# The solution are (-0.75-1.1989578808281798j) and (-0.75+1.1989578808281798j)

# %%
#SWAP 2 NUMBERS
x = 5
y = 10

x, y = y, x
print("x =", x)

print("y =", y)
# Out:
# x = 10
# y = 5

# %%
#SWAP 2 NUMBERS
x = int(input('Enter value of x: '))
y = int(input('Enter value of y: '))

x, y = y, x
print("x =", x)
print("y =", y)
# Out:
# Enter value of x: 4
# Enter value of y: 6
# x = 6
# y = 4

# %%
# Python program to check if the number is an Armstrong number or not

# take input from the user
num = int(input("Enter a number: "))

# initialize sum
sum = 0

# find the sum of the cube of each digit
temp = num
while temp > 0:
   digit = temp % 10
   sum += digit ** 3
   temp //= 10

# display the result
if num == sum:
   print(num,"is an Armstrong number")
else:
   print(num,"is not an Armstrong number")
# Out:
# Enter a number: 371
# 371 is an Armstrong number

# %%
#to find gcd of 2 numbers
import math
  
x=int(input('the value of x: '))
y=int(input('the value of y: '))
print("The gcd of x and y is : ", end="")
print(math.gcd(x, y))
# Out:
# the value of x: 54
# the value of y: 24
# The gcd of x and y is : 6

# %%
#transpose of a matrix
import numpy
matrix=[[1,2,3],
        [4,5,6]]
print(matrix)
print('\n')
print(numpy.transpose(matrix))
# Out:
# [[1, 2, 3], [4, 5, 6]]
#
#
# [[1 4]
#  [2 5]
#  [3 6]]

# %%
X = [[12,7],
    [4 ,5],
    [3 ,8]]

result = [[0,0,0],
         [0,0,0]]

# iterate through rows
for i in range(len(X)):
   # iterate through columns
   for j in range(len(X[0])):
       result[j][i] = X[i][j]

for r in result:
   print(r)
# Out:
# [12, 4, 3]
# [7, 5, 8]

# %%
# Program to add two matrices using list comprehension

X = [[12,7,3],
    [4 ,5,6],
    [7 ,8,9]]

Y = [[5,8,1],
    [6,7,3],
    [4,5,9]]

result = [[X[i][j] + Y[i][j]  for j in range(len(X[0]))] for i in range(len(X))]

for r in result:
   print(r)
# Out:
# [17, 15, 4]
# [10, 12, 9]
# [11, 13, 18]

# %%
#sort dictionary by values
dt = {"A":90, "B":2, "C":3}

sorted_dt_value = sorted(dt.values())
print(dt)
print(sorted_dt_value)
# Out:
# {'A': 90, 'B': 2, 'C': 3}
# [2, 3, 90]

# %%
#sort dictionary by values
sorted_dic= {}
sorted_values = sorted(dic, key=dic.get) 

print("Original dictionary: ",dic)

for i in sorted_values:
    sorted_dic[i] = dic[i]
print("Sorted dictionary: ", sorted_dic)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13200\3766808556.py in <module>
#       1 #sort dictionary by values
#       2 sorted_dic= {}
# ----> 3 sorted_values = sorted(dic, key=dic.get)
#       4
#       5 print("Original dictionary: ",dic)
#
# NameError: name 'dic' is not defined

# %%
#program to convert string to datetime
from datetime import datetime

my_date_string = "Mar 11 2011 11:31AM"

datetime_object = datetime.strptime(my_date_string, '%b %d %Y %I:%M%p')

print(type(datetime_object))
print(datetime_object)
# Out:
# <class 'datetime.datetime'>
# 2011-03-11 11:31:00

# %%
#program to convert string to datetime
from datetime import datetime
date_object = datetime.strptime('Dec 7 2022 2:22PM', '%b %d %Y %I:%M%p')
print(date_object)
# Out:
# 2022-12-07 14:22:00

# %%
#program to reverse a number
num=int(input('enter no. to be reversed: '))
reversed_num = 0

while num != 0:
    digit = num % 10
    reversed_num = reversed_num * 10 + digit
    num //= 10

print("Reversed Number: " + str(reversed_num))
# Out:
# enter no. to be reversed: 432
# Reversed Number: 234

# %%
#program to find the power of a number
base = int(input(" the base: "))
exponent = int(input('the power : '))

result = 1

while exponent != 0:
    result *= base
    exponent-=1

print("Answer = " + str(result))
# Out:
#  the base: 5
# the power : 2
# Answer = 25

# %%
#program for countdown timer
import time

def countdown(time_sec):
    while time_sec:
        mins, secs = divmod(time_sec, 60)
        timeformat = '{:02d}:{:02d}'.format(mins, secs)
        print(timeformat, end='\r')
        time.sleep(1)
        time_sec -= 1

    print("stop ")

countdown(5)
# Out:
# stop

# %%
#program to convert byte to a string
data = b'GeeksForGeeks'
 
# display input
print('\nInput:')
print(data)
print(type(data))
 
# converting
output = data.decode()
 
# display output
print('\nOutput:')
print(output)
print(type(output))
# Out:
# Input:
# b'GeeksForGeeks'
# <class 'bytes'>
#
# Output:
# GeeksForGeeks
# <class 'str'>
